# %%
import pandas as pd
from datetime import datetime

# %%
timestamp = pd.Timestamp(datetime(1999,10,14))

# %%
timestamp.year
# Out:
# 1999

# %%
pd.Period("2023-05", "Q")\
    .asfreq("D")
# Out:
# Period('2023-06-30', 'D')

# %%
google_df = pd.read_csv("../../Datasets/google.csv")

# %%
google_df
# Out:
#             Date   Close
# 0     2014-01-02  556.00
# 1     2014-01-03  551.95
# 2     2014-01-04     NaN
# 3     2014-01-05     NaN
# 4     2014-01-06  558.10
# ...          ...     ...
# 1089  2016-12-26     NaN
# 1090  2016-12-27  791.55
# 1091  2016-12-28  785.05
# 1092  2016-12-29  782.79
# 1093  2016-12-30  771.82
#
# [1094 rows x 2 columns]

# %%
google_df.Close.plot()
# Out:
# <Axes: >
